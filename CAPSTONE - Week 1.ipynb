# %% [markdown]
# Clearly define a problem or an idea of your choice, where you would need to leverage the Foursquare location data to solve or execute. Remember that data science problems always target an audience and are meant to help a group of stakeholders solve a problem, so make sure that you explicitly describe your audience and why they would care about your problem.

# %% [markdown]
# My capstone project will look at the feasibility of opening a sidewalk cafe in Washington D.C.  The audience for this project will be stakeholders in the opening of a new cafe, looking to maximize the probability of success. This project aims to identify the best café location based on the density/clustering of existing sidewalk cafés and analysis of popularity/foot traffic.

# %% [markdown]
# Describe the data that you will be using to solve the problem or execute your idea. Remember that you will need to use the Foursquare location data to solve the problem or execute your idea. You can absolutely use other datasets in combination with the Foursquare location data. So make sure that you provide adequate explanation and discussion, with examples, of the data that you will be using, even if it is only Foursquare location data.
#
# I will use two primary data sets in this project
# -	The Sidewalk Café location data set from Open Data DC contains locations and attributes of sidewalk cafes.  The location data will be used to find sidewalk café density clusters and spatial distribution.  This data set is somewhat dated, with the last update being 6/25/2019 but I believe it will still work for the purposes of this project.
# -	The Foursquare locations data will be used to get supplemental geospatial information on the sidewalk café locations.  Additionally, the Foursquare user count and tips data will be used be used to determine popularity/foot traffic at each location.
# For the sake of simplicity, the following methodology will be used:
# -	Scrape Open Data DC for sidewalk café location in Washington D.C.
# -	Query Foursquare API for supplemental geospatial information on sidewalk café locations.
# -	Find Foursquare user and tip data around each café cluster.

# %%
import numpy as np
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
import json 
# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim
import requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe
import matplotlib.cm as cm
import matplotlib.colors as colors
from sklearn.cluster import KMeans
# !conda install -c conda-forge folium=0.5.0 --yes 
import folium
print('Libraries imported.')
# Out:
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python36
#
#   added / updated specs:
#     - geopy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     openssl-1.1.1g             |       h516909a_0         2.1 MB  conda-forge
#     geopy-1.21.0               |             py_0          58 KB  conda-forge
#     geographiclib-1.50         |             py_0          34 KB  conda-forge
#     python_abi-3.6             |          1_cp36m           4 KB  conda-forge
#     ca-certificates-2020.4.5.1 |       hecc5488_0         146 KB  conda-forge
#     certifi-2020.4.5.1         |   py36h9f0ad1d_0         151 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         2.5 MB
#
# The following NEW packages will be INSTALLED:
#
#     geographiclib:   1.50-py_0         conda-forge
#     geopy:           1.21.0-py_0       conda-forge
#     python_abi:      3.6-1_cp36m       conda-forge
#
# The following packages will be UPDATED:
#
#     ca-certificates: 2020.1.1-0                    --> 2020.4.5.1-hecc5488_0     conda-forge
#     certifi:         2020.4.5.1-py36_0             --> 2020.4.5.1-py36h9f0ad1d_0 conda-forge
#     openssl:         1.1.1g-h7b6447c_0             --> 1.1.1g-h516909a_0         conda-forge
#
#
# Downloading and Extracting Packages
# openssl-1.1.1g       | 2.1 MB    | ##################################### | 100%
# geopy-1.21.0         | 58 KB     | ##################################### | 100%
# geographiclib-1.50   | 34 KB     | ##################################### | 100%
# python_abi-3.6       | 4 KB      | ##################################### | 100%
# ca-certificates-2020 | 146 KB    | ##################################### | 100%
# certifi-2020.4.5.1   | 151 KB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python36
#
#   added / updated specs:
#     - folium=0.5.0
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     vincent-0.4.4              |             py_1          28 KB  conda-forge
#     folium-0.5.0               |             py_0          45 KB  conda-forge
#     altair-4.1.0               |             py_1         614 KB  conda-forge
#     branca-0.4.0               |             py_0          26 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         713 KB
#
# The following NEW packages will be INSTALLED:
#
#     altair:  4.1.0-py_1 conda-forge
#     branca:  0.4.0-py_0 conda-forge
#     folium:  0.5.0-py_0 conda-forge
#     vincent: 0.4.4-py_1 conda-forge
#
#
# Downloading and Extracting Packages
# vincent-0.4.4        | 28 KB     | ##################################### | 100%
# folium-0.5.0         | 45 KB     | ##################################### | 100%
# altair-4.1.0         | 614 KB    | ##################################### | 100%
# branca-0.4.0         | 26 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Libraries imported.

# %%
CLIENT_ID=''#Client ID removed for security
CLIENT_SECRET='' #Client Secret removed for security
VERSION='20180605' 
LIMIT=100
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID:
# CLIENT_SECRET:

# %%
# Get longitude and latitude for Toronto
address='Washington D.C., Washington D.C'
geolocator = Nominatim(user_agent="foursquare_agent")
location=geolocator.geocode(address)
latitude=location.latitude
longitude=location.longitude
print('The geograpical coordinate of Washington D.C. is {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Washington D.C. is 38.8949855, -77.0365708.

# %%
search_query = 'Cafe'
radius = 5000
print(search_query + ' .... OK!')
# Out:
# Cafe .... OK!

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=2AVVRRGUGU0NPIHPCZZ0ZRSNCA2J4YNAKPEAPJUYXNZ51CJ2&client_secret=T3FXGQEAGUZXND2322MEQ54XBNZJPNVOJXMQFPMJTU2XS1BN&ll=38.8949855,-77.0365708&v=20180605&query=Cafe&radius=5000&limit=100'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5eb02847ad1ab4001b80f27a'},
#  'response': {'venues': [{'id': '4a9b1b0bf964a5206d3420e3',
#     'name': 'Café du Parc',
#     'location': {'address': '1401 Pennsylvania Ave NW',
#      'crossStreet': 'at 14th St',
#      'lat': 38.896497,
#      'lng': -77.032618,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.896497,
#        'lng': -77.032618}],
#      'distance': 381,
#      'postalCode': '20004',
#      'cc': 'US',
#      'city': 'Washington',
#      'state': 'D.C.',
#      'country': 'United States',
#      'formattedAddress': ['1401 Pennsylvania Ave NW (at 14th St)',
#       'Washington, D.C. 20004',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d10c941735',
#       'name': 'French Restaurant',
#       'pluralName': 'French Restaurants',
#       'shortName': 'French',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/french_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '86322170'},
#     'referralId': 'v-1588603038',
#     'hasPerk': False},
#    {'id': '4eeba201d3e3d34eb11432b1',
#     'name': 'Flagship Cafe',
#     'location': {'address': '1331 Pennsylvania Ave NW',
#      'lat': 38.895998714861896,
#      'lng': -77.03153492414802,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.895998714861896,
#        'lng': -77.03153492414802}],
#      'distance': 450,
#      'postalCode': '20004',
#      'cc': 'US',
#      'city': 'Washington',
#      'state': 'D.C.',
#      'country': 'United States',
#      'formattedAddress': ['1331 Pennsylvania Ave NW',
#       'Washington, D.C. 20004',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588603038',
#     'hasPerk': False},
#    {'id': '4cd2efd240d4594138ae9a41',
#     'name': 'Soho Cafe & Market',
#     'location': {'address': '529 14th St NW',
#      'lat': 38.89693256878712,
#      'lng': -77.03165439187086,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.89693256878712,
#        'lng': -77.03165439187086},
#       {'label': 'entrance', 'lat': 38.897006, 'lng': -77.031764}],
#      'distance': 477,
#      'postalCode': '20045',
#      'cc': 'US',
#      'city': 'Washington',
#      'state': 'D.C.',
#      'country': 'United States',
#      'formattedAddress': ['529 14th St NW',
#       'Washington, D.C. 20045',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588603038',
#     'hasPerk': False},
#    {'id': '4fc26ad7e4b02db73e8950cb',
#     'name': 'Holocaust Museum Cafe',
#     'location': {'address': '100 Raoul Wallenberg Place SW',
#      'lat': 38.88713574627168,
#      'lng': -77.03382579433485,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.88713574627168,
#        'lng': -77.03382579433485}],
#      'distance': 905,
#      'cc': 'US',
#      'neighborhood': 'Southwest Washington',
#      'state': 'Washington, D.C.',
#      'country': 'United States',
#      'formattedAddress': ['100 Raoul Wallenberg Place SW',
#       'Washington, D.C.',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588603038',
#     'hasPerk': False},
#    {'id': '4aa92f87f964a520575220e3',
#     'name': 'K Street Cafe & Bagel',
#     'location': {'address': '2000 K St NW',
#      'crossStreet': 'at 20th St NW',
#      'lat': 38.90230187352699,
#      'lng': -77.04539586333823,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.90230187352699,
#        'lng': -77.04539586333823}],
#      'distance': 1117,
#      'postalCode': '20006',
#      'cc': 'US',
#      'city': 'Washington',
#      'state': 'D.C.',
#      'country': 'United States',
#      'formattedAddress': ['2000 K St NW (at 20th St NW)',
#       'Washington, D.C. 20006',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d179941735',
#       'name': 'Bagel Shop',
#       'pluralName': 'Bagel Shops',
#       'shortName': 'Bagels',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bagels_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588603038',
#     'hasPerk': False},
#    {'id': '4cdc15364006a1434a72dcb2',
#     'name': 'Esprinto Cafe',
#     'location': {'address': '1331 Pennsylvania Ave NW',
#      'lat': 38.89734056306548,
#      'lng': -77.030168291745,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.89734056306548,
#        'lng': -77.030168291745},
#       {'label': 'entrance', 'lat': 38.897085, 'lng': -77.029824}],
#      'distance': 613,
#      'postalCode': '20004',
#      'cc': 'US',
#      'city': 'Washington',
#      'state': 'D.C.',
#      'country': 'United States',
#      'formattedAddress': ['1331 Pennsylvania Ave NW',
#       'Washington, D.C. 20004',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588603038',
#     'hasPerk': False},
#    {'id': '44d31e22f964a5203d361fe3',
#     'name': 'Juan Valdez Cafe',
#     'location': {'address': '1889 F St NW',
#      'crossStreet': 'at 19th St NW',
#      'lat': 38.89745645130179,
#      'lng': -77.04334068952726,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.89745645130179,
#        'lng': -77.04334068952726}],
#      'distance': 647,
#      'postalCode': '20006',
#      'cc': 'US',
#      'city': 'Washington',
#      'state': 'D.C.',
#      'country': 'United States',
#      'formattedAddress': ['1889 F St NW (at 19th St NW)',
#       'Washington, D.C. 20006',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '88328513'},
#     'referralId': 'v-1588603038',
#     'hasPerk': False},
#    {'id': '4a9ffb83f964a520d63d20e3',
#     'name': 'An Uncommon Cafe',
#     'location': {'address': '1800 G St NW',
#      'crossStreet': 'btwn 18th & 19th St NW',
#      'lat': 38.898412080855614,
#      'lng': -77.04279964958818,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.898412080855614,
#        'lng': -77.04279964958818}],
#      'distance': 660,
#      'postalCode': '20006',
#      'cc': 'US',
#      'city': 'Washington',
#      'state': 'D.C.',
#      'country': 'United States',
#      'formattedAddress': ['1800 G St NW (btwn 18th & 19th St NW)',
#       'Washington, D.C. 20006',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588603038',
#     'hasPerk': False},
#    {'id': '57f91c81498e3ba5808c29c1',
#     'name': 'Northstar Cafe',
#     'location': {'lat': 38.891205,
#      'lng': -77.03261,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.891205,
#        'lng': -77.03261}],
#      'distance': 543,
#      'postalCode': '20230',
#      'cc': 'US',
#      'city': 'Washington',
#      'state': 'D.C.',
#      'country': 'United States',
#      'formattedAddress': ['Washington, D.C. 20230', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d14e941735',
#       'name': 'American Restaurant',
#       'pluralName': 'American Restaurants',
#       'shortName': 'American',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588603038',
#     'hasPerk': False},
#    {'id': '4a7b0ecdf964a520e6e91fe3',
#     'name': 'Gallery Cafe',
#     'location': {'address': '1401 H St NW',
#      'crossStreet': 'at 14th St NW',
#      'lat': 38.900639654182626,
#      'lng': -77.03218191862106,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.900639654182626,
#        'lng': -77.03218191862106}],
#      'distance': 735,
#      'postalCode': '20005',
#      'cc': 'US',
#      'city': 'Washington',
#      'state': 'D.C.',
#      'country': 'United States',
#      'formattedAddress': ['1401 H St NW (at 14th St NW)',
#       'Washington, D.C. 20005',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1c5941735',
#       'name': 'Sandwich Place',
#       'pluralName': 'Sandwich Places',
#       'shortName': 'Sandwiches',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588603038',
#     'hasPerk': False},
#    {'id': '4b9931faf964a520d26835e3',
#     'name': 'Cafe Soleil',
#     'location': {'address': '839 17th St NW',
#      'crossStreet': 'at I St NW',
#      'lat': 38.90108222289659,
#      'lng': -77.03942260864373,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.90108222289659,
#        'lng': -77.03942260864373},
#       {'label': 'entrance', 'lat': 38.90108, 'lng': -77.039262}],
#      'distance': 722,
#      'postalCode': '20006',
#      'cc': 'US',
#      'city': 'Washington',
#      'state': 'D.C.',
#      'country': 'United States',
#      'formattedAddress': ['839 17th St NW (at I St NW)',
#       'Washington, D.C. 20006',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d10c941735',
#       'name': 'French Restaurant',
#       'pluralName': 'French Restaurants',
#       'shortName': 'French',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/french_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '49731015'},
#     'referralId': 'v-1588603038',
#     'hasPerk': False},
#    {'id': '40b13b00f964a52047f71ee3',
#     'name': 'Cafe Mozart',
#     'location': {'address': '1331 H St NW',
#      'lat': 38.900495623989606,
#      'lng': -77.03058868646622,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.900495623989606,
#        'lng': -77.03058868646622}],
#      'distance': 803,
#      'postalCode': '20005',
#      'cc': 'US',
#      'city': 'Washington',
#      'state': 'D.C.',
#      'country': 'United States',
#      'formattedAddress': ['1331 H St NW',
#       'Washington, D.C. 20005',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d10d941735',
#       'name': 'German Restaurant',
#       'pluralName': 'German Restaurants',
#       'shortName': 'German',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/german_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '527064750'},
#     'referralId': 'v-1588603038',
#     'hasPerk': False},
#    {'id': '4ad0e92af964a52007db20e3',
#     'name': 'Stars & Stripes Cafe',
#     'location': {'address': 'National Museum of American History',
#      'lat': 38.891158759319026,
#      'lng': -77.03174894250354,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.891158759319026,
#        'lng': -77.03174894250354}],
#      'distance': 596,
#      'postalCode': '20024',
#      'cc': 'US',
#      'city': 'Washington',
#      'state': 'D.C.',
#      'country': 'United States',
#      'formattedAddress': ['National Museum of American History',
#       'Washington, D.C. 20024',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d128941735',
#       'name': 'Cafeteria',
#       'pluralName': 'Cafeterias',
#       'shortName': 'Cafeteria',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/cafeteria_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588603038',
#     'hasPerk': False},
#    {'id': '4c32042f452620a12e5e210f',
#     'name': 'Constitution Café',
#     'location': {'address': '1400 Constitution Ave NW',
#      'crossStreet': 'in National Museum of American History',
#      'lat': 38.89203513365936,
#      'lng': -77.03007399757483,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.89203513365936,
#        'lng': -77.03007399757483}],
#      'distance': 651,
#      'postalCode': '20560',
#      'cc': 'US',
#      'city': 'Washington',
#      'state': 'D.C.',
#      'country': 'United States',
#      'formattedAddress': ['1400 Constitution Ave NW (in National Museum of American History)',
#       'Washington, D.C. 20560',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d14e941735',
#       'name': 'American Restaurant',
#       'pluralName': 'American Restaurants',
#       'shortName': 'American',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '35659405'},
#     'referralId': 'v-1588603038',
#     'hasPerk': False},
#    {'id': '40b13b00f964a52079f41ee3',
#     'name': 'Hard Rock Cafe Washington DC',
#     'location': {'address': '999 E St NW',
#      'crossStreet': 'at 10th St NW',
#      'lat': 38.896353568868165,
#      'lng': -77.02584827918531,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.896353568868165,
#        'lng': -77.02584827918531},
#       {'label': 'entrance', 'lat': 38.896261, 'lng': -77.02554}],
#      'distance': 941,
#      'postalCode': '20004',
#      'cc': 'US',
#      'city': 'Washington',
#      'state': 'D.C.',
#      'country': 'United States',
#      'formattedAddress': ['999 E St NW (at 10th St NW)',
#       'Washington, D.C. 20004',
#       'United States']},
#     'categories': [{'id': '56aa371be4b08b9a8d573538',
#       'name': 'Theme Restaurant',
#       'pluralName': 'Theme Restaurants',
#       'shortName': 'Theme Restaurant',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588603038',
#     'hasPerk': False},
#    {'id': '542b16e4498ea5b0861d5d03',
#     'name': 'Van Houtte Café',
#     'location': {'address': '818 Connecticut Ave NW',
#      'lat': 38.90107884053043,
#      'lng': -77.03861033227523,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.90107884053043,
#        'lng': -77.03861033227523}],
#      'distance': 700,
#      'postalCode': '20006',
#      'cc': 'US',
#      'city': 'Washington',
#      'state': 'D.C.',
#      'country': 'United States',
#      'formattedAddress': ['818 Connecticut Ave NW',
#       'Washington, D.C. 20006',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588603038',
#     'hasPerk': False},
#    {'id': '4b1a7c72f964a520ffea23e3',
#     'name': 'Cafe Cozy Corner',
#     'location': {'address': '1117 10th St. NW',
#      'crossStreet': 'btwn L & M Sts. NW',
#      'lat': 38.904787396310184,
#      'lng': -77.02588164213586,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.904787396310184,
#        'lng': -77.02588164213586},
#       {'label': 'entrance', 'lat': 38.90476, 'lng': -77.025856}],
#      'distance': 1431,
#      'postalCode': '20001',
#      'cc': 'US',
#      'city': 'Washington',
#      'state': 'D.C.',
#      'country': 'United States',
#      'formattedAddress': ['1117 10th St. NW (btwn L & M Sts. NW)',
#       'Washington, D.C. 20001',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588603038',
#     'hasPerk': False},
#    {'id': '4bb61bcfef159c74036b75f7',
#     'name': 'The Green Cafe EcoCart',
#     'location': {'address': '101-199 Raoul Wallenberg Pl SW',
#      'lat': 38.88879608709441,
#      'lng': -77.0332013757215,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.88879608709441,
#        'lng': -77.0332013757215}],
#      'distance': 748,
#      'postalCode': '20024',
#      'cc': 'US',
#      'city': 'Washington',
#      'state': 'D.C.',
#      'country': 'United States',
#      'formattedAddress': ['101-199 Raoul Wallenberg Pl SW',
#       'Washington, D.C. 20024',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1cb941735',
#       'name': 'Food Truck',
#       'pluralName': 'Food Trucks',
#       'shortName': 'Food Truck',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/streetfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588603038',
#     'hasPerk': False},
#    {'id': '4c4616972dcd9c74f7b40a7b',
#     'name': 'Cafe Se7en',
#     'location': {'address': '500 8th St NW',
#      'lat': 38.8964674964982,
#      'lng': -77.0230295037406,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.8964674964982,
#        'lng': -77.0230295037406},
#       {'label': 'entrance', 'lat': 38.89651, 'lng': -77.023113}],
#      'distance': 1184,
#      'postalCode': '20004',
#      'cc': 'US',
#      'city': 'Washington',
#      'state': 'D.C.',
#      'country': 'United States',
#      'formattedAddress': ['500 8th St NW',
#       'Washington, D.C. 20004',
#       'United States']},
#     'categories': [{'id': '5665c7b9498e7d8a4f2c0f06',
#       'name': 'Corporate Coffee Shop',
#       'pluralName': 'Corporate Coffee Shops',
#       'shortName': 'Corporate Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588603038',
#     'hasPerk': False},
#    {'id': '49d0eb69f964a520405b1fe3',
#     'name': 'City Place Café',
#     'location': {'address': '1101 17th St NW',
#      'crossStreet': 'btwn L St & Sumner Row',
#      'lat': 38.904046,
#      'lng': -77.038714,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.904046,
#        'lng': -77.038714},
#       {'label': 'entrance', 'lat': 38.904042, 'lng': -77.038299}],
#      'distance': 1025,
#      'postalCode': '20036',
#      'cc': 'US',
#      'city': 'Washington',
#      'state': 'D.C.',
#      'country': 'United States',
#      'formattedAddress': ['1101 17th St NW (btwn L St & Sumner Row)',
#       'Washington, D.C. 20036',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '67601792'},
#     'referralId': 'v-1588603038',
#     'hasPerk': False},
#    {'id': '4b226639f964a520524624e3',
#     'name': 'Atrium Cafe - 1050 Connecticut',
#     'location': {'address': '1050 Connecticut Ave NW',
#      'crossStreet': 'at L Street',
#      'lat': 38.903735944650464,
#      'lng': -77.04024759918107,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.903735944650464,
#        'lng': -77.04024759918107},
#       {'label': 'entrance', 'lat': 38.903587, 'lng': -77.04017}],
#      'distance': 1024,
#      'postalCode': '20036',
#      'cc': 'US',
#      'city': 'Washington',
#      'state': 'D.C.',
#      'country': 'United States',
#      'formattedAddress': ['1050 Connecticut Ave NW (at L Street)',
#       'Washington, D.C. 20036',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1c5941735',
#       'name': 'Sandwich Place',
#       'pluralName': 'Sandwich Places',
#       'shortName': 'Sandwiches',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588603038',
#     'hasPerk': False},
#    {'id': '4b5f087cf964a52014a329e3',
#     'name': 'Soho Cafe',
#     'location': {'address': '1301 K St. NW',
#      'crossStreet': '13th St.',
#      'lat': 38.90268509230859,
#      'lng': -77.02982266679857,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.90268509230859,
#        'lng': -77.02982266679857}],
#      'distance': 1037,
#      'postalCode': '20005',
#      'cc': 'US',
#      'city': 'Washington',
#      'state': 'D.C.',
#      'country': 'United States',
#      'formattedAddress': ['1301 K St. NW (13th St.)',
#       'Washington, D.C. 20005',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'shortName': 'Restaurant',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588603038',
#     'hasPerk': False},
#    {'id': '4a96b618f964a520ad2620e3',
#     'name': 'Soho Cafe & Market',
#     'location': {'address': '1900 Pennsylvania Ave NW',
#      'crossStreet': '19th & Pennsylvania',
#      'lat': 38.900005,
#      'lng': -77.044268,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.900005,
#        'lng': -77.044268},
#       {'label': 'entrance', 'lat': 38.900237, 'lng': -77.044068}],
#      'distance': 870,
#      'cc': 'US',
#      'city': 'Washington',
#      'state': 'D.C.',
#      'country': 'United States',
#      'formattedAddress': ['1900 Pennsylvania Ave NW (19th & Pennsylvania)',
#       'Washington, D.C.',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'shortName': 'Restaurant',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588603038',
#     'hasPerk': False},
#    {'id': '51112106e4b0c5da227cfbfc',
#     'name': 'Fireside Cafe',
#     'location': {'address': '1825 I St NW',
#      'lat': 38.901919188563,
#      'lng': -77.04271468041738,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.901919188563,
#        'lng': -77.04271468041738}],
#      'distance': 937,
#      'postalCode': '20006',
#      'cc': 'US',
#      'city': 'Washington',
#      'state': 'D.C.',
#      'country': 'United States',
#      'formattedAddress': ['1825 I St NW',
#       'Washington, D.C. 20006',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588603038',
#     'hasPerk': False},
#    {'id': '4cdbfc3c22bd721e238af847',
#     'name': 'World Cafe',
#     'location': {'address': '1110 Vermont Ave NW',
#      'lat': 38.904328,
#      'lng': -77.03325600000001,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.904328,
#        'lng': -77.03325600000001},
#       {'label': 'entrance', 'lat': 38.904233, 'lng': -77.033045}],
#      'distance': 1078,
#      'postalCode': '20006',
#      'cc': 'US',
#      'city': 'Washington',
#      'state': 'D.C.',
#      'country': 'United States',
#      'formattedAddress': ['1110 Vermont Ave NW',
#       'Washington, D.C. 20006',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d146941735',
#       'name': 'Deli / Bodega',
#       'pluralName': 'Delis / Bodegas',
#       'shortName': 'Deli / Bodega',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588603038',
#     'hasPerk': False},
#    {'id': '53762fa0498e37ec0e970d61',
#     'name': 'Cafe Deluxe',
#     'location': {'address': '2200 M St NW',
#      'lat': 38.90539830292653,
#      'lng': -77.04887840948969,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.90539830292653,
#        'lng': -77.04887840948969}],
#      'distance': 1574,
#      'postalCode': '20037',
#      'cc': 'US',
#      'city': 'Washington',
#      'state': 'D.C.',
#      'country': 'United States',
#      'formattedAddress': ['2200 M St NW',
#       'Washington, D.C. 20037',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d14e941735',
#       'name': 'American Restaurant',
#       'pluralName': 'American Restaurants',
#       'shortName': 'American',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588603038',
#     'hasPerk': False},
#    {'id': '4fe06043e4b01c7416de39f3',
#     'name': 'The Gatehouse Cafe',
#     'location': {'address': '1199 Vermont Ave NW',
#      'lat': 38.90443592373471,
#      'lng': -77.03245354876279,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.90443592373471,
#        'lng': -77.03245354876279}],
#      'distance': 1110,
#      'postalCode': '20005',
#      'cc': 'US',
#      'city': 'Washington',
#      'state': 'D.C.',
#      'country': 'United States',
#      'formattedAddress': ['1199 Vermont Ave NW',
#       'Washington, D.C. 20005',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588603038',
#     'hasPerk': False},
#    {'id': '4e85eadf9adf501dc286a798',
#     'name': "Atrium Cafe - Smithsonian's National Museum of Natural History",
#     'location': {'address': '10th St. & Constitution Ave. NW, Washington, DC 20560, United States',
#      'crossStreet': 'at 10th St NW',
#      'lat': 38.89140342548594,
#      'lng': -77.02613387804203,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.89140342548594,
#        'lng': -77.02613387804203}],
#      'distance': 988,
#      'postalCode': '20560',
#      'cc': 'US',
#      'city': 'Washington',
#      'state': 'D.C.',
#      'country': 'United States',
#      'formattedAddress': ['10th St. & Constitution Ave. NW, Washington, DC 20560, United States (at 10th St NW)',
#       'Washington, D.C. 20560',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588603038',
#     'hasPerk': False},
#    {'id': '4b8ef33af964a520934033e3',
#     'name': 'Gallery Salad Bar & Grill Cafe',
#     'location': {'address': '616 23rd St NW',
#      'lat': 38.898160141428434,
#      'lng': -77.05029430889456,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.898160141428434,
#        'lng': -77.05029430889456},
#       {'label': 'entrance', 'lat': 38.898072, 'lng': -77.050309}],
#      'distance': 1240,
#      'postalCode': '20050',
#      'cc': 'US',
#      'city': 'Washington',
#      'state': 'D.C.',
#      'country': 'United States',
#      'formattedAddress': ['616 23rd St NW',
#       'Washington, D.C. 20050',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d120951735',
#       'name': 'Food Court',
#       'pluralName': 'Food Courts',
#       'shortName': 'Food Court',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_foodcourt_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588603038',
#     'hasPerk': False},
#    {'id': '4ccaf5d5b571b60c31c4c865',
#     'name': 'Uptowner Cafe',
#     'location': {'address': '2400 M St NW',
#      'crossStreet': 'btwn L & M St NW',
#      'lat': 38.90483689364071,
#      'lng': -77.05162581961929,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.90483689364071,
#        'lng': -77.05162581961929},
#       {'label': 'entrance', 'lat': 38.905149, 'lng': -77.052048}],
#      'distance': 1704,
#      'postalCode': '20037',
#      'cc': 'US',
#      'city': 'Washington',
#      'state': 'D.C.',
#      'country': 'United States',
#      'formattedAddress': ['2400 M St NW (btwn L & M St NW)',
#       'Washington, D.C. 20037',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d146941735',
#       'name': 'Deli / Bodega',
#       'pluralName': 'Delis / Bodegas',
#       'shortName': 'Deli / Bodega',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '2027225',
#      'url': 'https://www.grubhub.com/restaurant/uptowner-cafe-2400-m-st-nw-washington/2027225?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2027225',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'venuePage': {'id': '98085973'},
#     'referralId': 'v-1588603038',
#     'hasPerk': False},
#    {'id': '4b2903f6f964a5205d9724e3',
#     'name': "The Work's Cafe",
#     'location': {'address': '1145 19th St NW, Rear LOBBY',
#      'lat': 38.90485371182369,
#      'lng': -77.04324317538881,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.90485371182369,
#        'lng': -77.04324317538881}],
#      'distance': 1241,
#      'postalCode': '20036',
#      'cc': 'US',
#      'city': 'Washington',
#      'state': 'D.C.',
#      'country': 'United States',
#      'formattedAddress': ['1145 19th St NW, Rear LOBBY',
#       'Washington, D.C. 20036',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588603038',
#     'hasPerk': False},
#    {'id': '4c0fc0b47189c9285592dab6',
#     'name': 'Watchdog Cafe',
#     'location': {'address': '441 G St NW',
#      'lat': 38.899454666336005,
#      'lng': -77.01622305624458,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.899454666336005,
#        'lng': -77.01622305624458},
#       {'label': 'entrance', 'lat': 38.898547, 'lng': -77.017513}],
#      'distance': 1831,
#      'postalCode': '20548',
#      'cc': 'US',
#      'city': 'Washington',
#      'state': 'D.C.',
#      'country': 'United States',
#      'formattedAddress': ['441 G St NW',
#       'Washington, D.C. 20548',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d120951735',
#       'name': 'Food Court',
#       'pluralName': 'Food Courts',
#       'shortName': 'Food Court',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_foodcourt_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588603038',
#     'hasPerk': False},
#    {'id': '4bae0ac5f964a520db7d3be3',
#     'name': 'Aroma Cafe',
#     'location': {'address': '2401 Pennsylvania Ave NW',
#      'crossStreet': 'at 24th St NW',
#      'lat': 38.90324067012936,
#      'lng': -77.05154787442379,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.90324067012936,
#        'lng': -77.05154787442379}],
#      'distance': 1589,
#      'cc': 'US',
#      'city': 'Washington',
#      'state': 'D.C.',
#      'country': 'United States',
#      'formattedAddress': ['2401 Pennsylvania Ave NW (at 24th St NW)',
#       'Washington, D.C.',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588603038',
#     'hasPerk': False},
#    {'id': '4bbb8216e5b0d13aa3216e7c',
#     'name': 'Capitol Cafe',
#     'location': {'address': '101 Constitution Ave NW',
#      'crossStreet': '2nd Street',
#      'lat': 38.89290217302212,
#      'lng': -77.01345783404058,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.89290217302212,
#        'lng': -77.01345783404058},
#       {'label': 'entrance', 'lat': 38.892372, 'lng': -77.013348}],
#      'distance': 2015,
#      'postalCode': '20001',
#      'cc': 'US',
#      'city': 'Washington',
#      'state': 'D.C.',
#      'country': 'United States',
#      'formattedAddress': ['101 Constitution Ave NW (2nd Street)',
#       'Washington, D.C. 20001',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588603038',
#     'hasPerk': False},
#    {'id': '4b5653def964a5208c0b28e3',
#     'name': 'Click! Cafe',
#     'location': {'address': '2000 N St NW',
#      'lat': 38.90664965116771,
#      'lng': -77.0452325071556,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.90664965116771,
#        'lng': -77.0452325071556}],
#      'distance': 1499,
#      'cc': 'US',
#      'city': 'District of Columbia',
#      'state': 'D.C.',
#      'country': 'United States',
#      'formattedAddress': ['2000 N St NW',
#       'District of Columbia, D.C.',
#       'United States']},
#     'categories': [{'id': '5665c7b9498e7d8a4f2c0f06',
#       'name': 'Corporate Coffee Shop',
#       'pluralName': 'Corporate Coffee Shops',
#       'shortName': 'Corporate Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588603038',
#     'hasPerk': False},
#    {'id': '4ca0afa27d69b713ec3e3fc2',
#     'name': 'Metro Cafe',
#     'location': {'address': '1400 16th St NW',
#      'crossStreet': 'at P St NW',
#      'lat': 38.90928368589371,
#      'lng': -77.03721290110441,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.90928368589371,
#        'lng': -77.03721290110441}],
#      'distance': 1592,
#      'postalCode': '20036',
#      'cc': 'US',
#      'city': 'Washington',
#      'state': 'D.C.',
#      'country': 'United States',
#      'formattedAddress': ['1400 16th St NW (at P St NW)',
#       'Washington, D.C. 20036',
#       'United States']},
#     'categories': [{'id': '5665c7b9498e7d8a4f2c0f06',
#       'name': 'Corporate Coffee Shop',
#       'pluralName': 'Corporate Coffee Shops',
#       'shortName': 'Corporate Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588603038',
#     'hasPerk': False},
#    {'id': '4bf59b5c4d5f20a1dec197fe',
#     'name': 'Avenue Cafe & Lounge',
#     'location': {'address': '1501 Rhode Island Avenue Northwest',
#      'crossStreet': 'at 15th St',
#      'lat': 38.90815,
#      'lng': -77.03502,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.90815,
#        'lng': -77.03502}],
#      'distance': 1471,
#      'postalCode': '20005',
#      'cc': 'US',
#      'city': 'Washington',
#      'state': 'D.C.',
#      'country': 'United States',
#      'formattedAddress': ['1501 Rhode Island Avenue Northwest (at 15th St)',
#       'Washington, D.C. 20005',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'shortName': 'Restaurant',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588603038',
#     'hasPerk': False},
#    {'id': '4b84126df964a520ea1e31e3',
#     'name': 'Courtyard Cafe',
#     'location': {'address': '800-898 G St NW',
#      'lat': 38.89796249779111,
#      'lng': -77.0229566636315,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.89796249779111,
#        'lng': -77.0229566636315}],
#      'distance': 1225,
#      'postalCode': '20001',
#      'cc': 'US',
#      'city': 'Washington',
#      'state': 'D.C.',
#      'country': 'United States',
#      'formattedAddress': ['800-898 G St NW',
#       'Washington, D.C. 20001',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588603038',
#     'hasPerk': False},
#    {'id': '55c7d79a498e846e84ad8f0c',
#     'name': '14th St Cafe Asian Bistro',
#     'location': {'address': '1416 14th St NW',
#      'lat': 38.90951696014983,
#      'lng': -77.03205027041216,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.90951696014983,
#        'lng': -77.03205027041216}],
#      'distance': 1664,
#      'postalCode': '20005',
#      'cc': 'US',
#      'city': 'Washington',
#      'state': 'D.C.',
#      'country': 'United States',
#      'formattedAddress': ['1416 14th St NW',
#       'Washington, D.C. 20005',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d142941735',
#       'name': 'Asian Restaurant',
#       'pluralName': 'Asian Restaurants',
#       'shortName': 'Asian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588603038',
#     'hasPerk': False},
#    {'id': '4bad124cf964a5209f2a3be3',
#     'name': 'Pavilion Cafe',
#     'location': {'address': '7th St. NW',
#      'crossStreet': 'Constitution Ave.',
#      'lat': 38.891274507088085,
#      'lng': -77.02331686913745,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.891274507088085,
#        'lng': -77.02331686913745}],
#      'distance': 1220,
#      'postalCode': '20565',
#      'cc': 'US',
#      'city': 'Washington',
#      'state': 'D.C.',
#      'country': 'United States',
#      'formattedAddress': ['7th St. NW (Constitution Ave.)',
#       'Washington, D.C. 20565',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '80050870'},
#     'referralId': 'v-1588603038',
#     'hasPerk': False},
#    {'id': '4b44eb9ef964a520d5ff25e3',
#     'name': 'Blu Cafe',
#     'location': {'address': '1170 22nd St NW',
#      'crossStreet': 'at Sports Club/LA In Ritz-Carlton',
#      'lat': 38.90498210038523,
#      'lng': -77.04877107412509,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.90498210038523,
#        'lng': -77.04877107412509}],
#      'distance': 1534,
#      'postalCode': '20037',
#      'cc': 'US',
#      'city': 'Washington',
#      'state': 'D.C.',
#      'country': 'United States',
#      'formattedAddress': ['1170 22nd St NW (at Sports Club/LA In Ritz-Carlton)',
#       'Washington, D.C. 20037',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588603038',
#     'hasPerk': False},
#    {'id': '40b3de00f964a5202b001fe3',
#     'name': 'Kramerbooks & Afterwords Cafe',
#     'location': {'address': '1517 Connecticut Ave NW',
#      'crossStreet': 'at Q St NW',
#      'lat': 38.91075587058406,
#      'lng': -77.0438804567901,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.91075587058406,
#        'lng': -77.0438804567901}],
#      'distance': 1866,
#      'postalCode': '20036',
#      'cc': 'US',
#      'city': 'Washington',
#      'state': 'D.C.',
#      'country': 'United States',
#      'formattedAddress': ['1517 Connecticut Ave NW (at Q St NW)',
#       'Washington, D.C. 20036',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d114951735',
#       'name': 'Bookstore',
#       'pluralName': 'Bookstores',
#       'shortName': 'Bookstore',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/bookstore_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '1165255',
#      'url': 'https://www.grubhub.com/restaurant/kramerbooks--afterwords-caf-1517-connecticut-ave-nw-washington/1165255?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1165255',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'venuePage': {'id': '32833274'},
#     'referralId': 'v-1588603038',
#     'hasPerk': False},
#    {'id': '4d89e884bc848cfa7ebacc2b',
#     'name': 'HUD Cyber Cafe',
#     'location': {'lat': 38.884264556022295,
#      'lng': -77.023103989973,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.884264556022295,
#        'lng': -77.023103989973}],
#      'distance': 1669,
#      'postalCode': '20585',
#      'cc': 'US',
#      'city': 'Washington',
#      'state': 'D.C.',
#      'country': 'United States',
#      'formattedAddress': ['Washington, D.C. 20585', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d14e941735',
#       'name': 'American Restaurant',
#       'pluralName': 'American Restaurants',
#       'shortName': 'American',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588603038',
#     'hasPerk': False},
#    {'id': '4e63e23e7d8b85408a4a84d3',
#     'name': 'Garden Café',
#     'location': {'address': 'National Gallery of Art',
#      'lat': 38.89131983551087,
#      'lng': -77.01993894416144,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.89131983551087,
#        'lng': -77.01993894416144}],
#      'distance': 1497,
#      'postalCode': '20001',
#      'cc': 'US',
#      'city': 'Washington',
#      'state': 'D.C.',
#      'country': 'United States',
#      'formattedAddress': ['National Gallery of Art',
#       'Washington, D.C. 20001',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588603038',
#     'hasPerk': False},
#    {'id': '4a416e1bf964a5204ba51fe3',
#     'name': 'Cafe Tu-O-Tu',
#     'location': {'address': '2816 Pennsylvania Ave NW',
#      'crossStreet': 'at 29th St. NW',
#      'lat': 38.90509566320447,
#      'lng': -77.0575585540409,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.90509566320447,
#        'lng': -77.0575585540409},
#       {'label': 'entrance', 'lat': 38.904971, 'lng': -77.05764}],
#      'distance': 2138,
#      'postalCode': '20007',
#      'cc': 'US',
#      'city': 'Washington',
#      'state': 'D.C.',
#      'country': 'United States',
#      'formattedAddress': ['2816 Pennsylvania Ave NW (at 29th St. NW)',
#       'Washington, D.C. 20007',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1c0941735',
#       'name': 'Mediterranean Restaurant',
#       'pluralName': 'Mediterranean Restaurants',
#       'shortName': 'Mediterranean',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mediterranean_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '84916954'},
#     'referralId': 'v-1588603038',
#     'hasPerk': False},
#    {'id': '4e4e5d45bd4101d0d7a88b94',
#     'name': 'Cascade Cafe',
#     'location': {'address': '6th & Constitution Ave NW',
#      'lat': 38.89136062496509,
#      'lng': -77.01789963974805,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.89136062496509,
#        'lng': -77.01789963974805}],
#      'distance': 1667,
#      'postalCode': '20565',
#      'cc': 'US',
#      'city': 'Washington',
#      'state': 'D.C.',
#      'country': 'United States',
#      'formattedAddress': ['6th & Constitution Ave NW',
#       'Washington, D.C. 20565',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588603038',
#     'hasPerk': False},
#    {'id': '4b212c13f964a520ae3724e3',
#     'name': 'Cafe Phillips',
#     'location': {'address': '50 F St NW',
#      'crossStreet': 'at North Capitol St NW',
#      'lat': 38.89750944753065,
#      'lng': -77.01015727587074,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.89750944753065,
#        'lng': -77.01015727587074},
#       {'label': 'entrance', 'lat': 38.897203, 'lng': -77.010336}],
#      'distance': 2305,
#      'postalCode': '20001',
#      'cc': 'US',
#      'city': 'Washington',
#      'state': 'D.C.',
#      'country': 'United States',
#      'formattedAddress': ['50 F St NW (at North Capitol St NW)',
#       'Washington, D.C. 20001',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1c5941735',
#       'name': 'Sandwich Place',
#       'pluralName': 'Sandwich Places',
#       'shortName': 'Sandwiches',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588603038',
#     'hasPerk': False},
#    {'id': '4d87dff124bf145691eabd5d',
#     'name': 'Cafe Eagle',
#     'location': {'address': '1414 9th St NW',
#      'crossStreet': 'at P St. NW',
#      'lat': 38.909206625343664,
#      'lng': -77.02423839349174,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.909206625343664,
#        'lng': -77.02423839349174}],
#      'distance': 1909,
#      'postalCode': '20001',
#      'cc': 'US',
#      'city': 'Washington',
#      'state': 'D.C.',
#      'country': 'United States',
#      'formattedAddress': ['1414 9th St NW (at P St. NW)',
#       'Washington, D.C. 20001',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1c1941735',
#       'name': 'Mexican Restaurant',
#       'pluralName': 'Mexican Restaurants',
#       'shortName': 'Mexican',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mexican_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588603038',
#     'hasPerk': False},
#    {'id': '5650d1c138fa31e5c8ca23e1',
#     'name': 'Dacha Cafe',
#     'location': {'address': '1602 7th St NW',
#      'lat': 38.911286878555366,
#      'lng': -77.02204654771617,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.911286878555366,
#        'lng': -77.02204654771617}],
#      'distance': 2208,
#      'postalCode': '20001',
#      'cc': 'US',
#      'city': 'Washington',
#      'state': 'D.C.',
#      'country': 'United States',
#      'formattedAddress': ['1602 7th St NW',
#       'Washington, D.C. 20001',
#       'United States']},
#     'categories': [{'id': '50be8ee891d4fa8dcc7199a7',
#       'name': 'Market',
#       'pluralName': 'Markets',
#       'shortName': 'Market',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/market_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588603038',
#     'hasPerk': False},
#    {'id': '50f460a4e4b0447167368a7e',
#     'name': 'Firehook Cafe (Natl. Building Museum)',
#     'location': {'address': '401 F Street NW',
#      'crossStreet': 'Fifth St NW',
#      'lat': 38.897743555555344,
#      'lng': -77.01785031740084,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.897743555555344,
#        'lng': -77.01785031740084}],
#      'distance': 1650,
#      'postalCode': '20001',
#      'cc': 'US',
#      'city': 'Washington',
#      'state': 'D.C.',
#      'country': 'United States',
#      'formattedAddress': ['401 F Street NW (Fifth St NW)',
#       'Washington, D.C. 20001',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588603038',
#     'hasPerk': False}]}}

# %%
venues=results['response']['venues']
dataframe=json_normalize(venues)
dataframe.head()
# Out:
#                                           categories delivery.id  \
# 0  [{'id': '4bf58dd8d48988d10c941735', 'name': 'F...         NaN
# 1  [{'id': '4bf58dd8d48988d16d941735', 'name': 'C...         NaN
# 2  [{'id': '4bf58dd8d48988d16d941735', 'name': 'C...         NaN
# 3  [{'id': '4bf58dd8d48988d16d941735', 'name': 'C...         NaN
# 4  [{'id': '4bf58dd8d48988d179941735', 'name': 'B...         NaN
#
#   delivery.provider.icon.name delivery.provider.icon.prefix  \
# 0                         NaN                           NaN
# 1                         NaN                           NaN
# 2                         NaN                           NaN
# 3                         NaN                           NaN
# 4                         NaN                           NaN
#
#   delivery.provider.icon.sizes delivery.provider.name delivery.url  hasPerk  \
# 0                          NaN                    NaN          NaN    False
# 1                          NaN                    NaN          NaN    False
# 2                          NaN                    NaN          NaN    False
# 3                          NaN                    NaN          NaN    False
# 4                          NaN                    NaN          NaN    False
#
#                          id               location.address location.cc  \
# 0  4a9b1b0bf964a5206d3420e3       1401 Pennsylvania Ave NW          US
# 1  4eeba201d3e3d34eb11432b1       1331 Pennsylvania Ave NW          US
# 2  4cd2efd240d4594138ae9a41                 529 14th St NW          US
# 3  4fc26ad7e4b02db73e8950cb  100 Raoul Wallenberg Place SW          US
# 4  4aa92f87f964a520575220e3                   2000 K St NW          US
#
#   location.city location.country location.crossStreet  location.distance  \
# 0    Washington    United States           at 14th St                381
# 1    Washington    United States                  NaN                450
# 2    Washington    United States                  NaN                477
# 3           NaN    United States                  NaN                905
# 4    Washington    United States        at 20th St NW               1117
#
#                            location.formattedAddress  \
# 0  [1401 Pennsylvania Ave NW (at 14th St), Washin...
# 1  [1331 Pennsylvania Ave NW, Washington, D.C. 20...
# 2  [529 14th St NW, Washington, D.C. 20045, Unite...
# 3  [100 Raoul Wallenberg Place SW, Washington, D....
# 4  [2000 K St NW (at 20th St NW), Washington, D.C...
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'label': 'display', 'lat': 38.896497, 'lng':...     38.896497
# 1  [{'label': 'display', 'lat': 38.89599871486189...     38.895999
# 2  [{'label': 'display', 'lat': 38.89693256878712...     38.896933
# 3  [{'label': 'display', 'lat': 38.88713574627168...     38.887136
# 4  [{'label': 'display', 'lat': 38.90230187352699...     38.902302
#
#    location.lng location.neighborhood location.postalCode    location.state  \
# 0    -77.032618                   NaN               20004              D.C.
# 1    -77.031535                   NaN               20004              D.C.
# 2    -77.031654                   NaN               20045              D.C.
# 3    -77.033826  Southwest Washington                 NaN  Washington, D.C.
# 4    -77.045396                   NaN               20006              D.C.
#
#                     name    referralId venuePage.id
# 0           Café du Parc  v-1588603038     86322170
# 1          Flagship Cafe  v-1588603038          NaN
# 2     Soho Cafe & Market  v-1588603038          NaN
# 3  Holocaust Museum Cafe  v-1588603038          NaN
# 4  K Street Cafe & Bagel  v-1588603038          NaN

# %%
filtered_columns=['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered=dataframe.loc[:, filtered_columns]
def get_category_type(row):
    try:
        categories_list=row['categories']
    except:
        categories_list=row['venue.categories']
        
    if len(categories_list)==0:
        return None
    else:
        return categories_list[0]['name']
dataframe_filtered['categories']=dataframe_filtered.apply(get_category_type, axis=1)
dataframe_filtered.columns=[column.split('.')[-1] for column in dataframe_filtered.columns]
dataframe_filtered
# Out:
#                                                  name  \
# 0                                        Café du Parc
# 1                                       Flagship Cafe
# 2                                  Soho Cafe & Market
# 3                               Holocaust Museum Cafe
# 4                               K Street Cafe & Bagel
# 5                                       Esprinto Cafe
# 6                                    Juan Valdez Cafe
# 7                                    An Uncommon Cafe
# 8                                      Northstar Cafe
# 9                                        Gallery Cafe
# 10                                        Cafe Soleil
# 11                                        Cafe Mozart
# 12                               Stars & Stripes Cafe
# 13                                  Constitution Café
# 14                       Hard Rock Cafe Washington DC
# 15                                    Van Houtte Café
# 16                                   Cafe Cozy Corner
# 17                             The Green Cafe EcoCart
# 18                                         Cafe Se7en
# 19                                    City Place Café
# 20                     Atrium Cafe - 1050 Connecticut
# 21                                          Soho Cafe
# 22                                 Soho Cafe & Market
# 23                                      Fireside Cafe
# 24                                         World Cafe
# 25                                        Cafe Deluxe
# 26                                 The Gatehouse Cafe
# 27  Atrium Cafe - Smithsonian's National Museum of...
# 28                     Gallery Salad Bar & Grill Cafe
# 29                                      Uptowner Cafe
# 30                                    The Work's Cafe
# 31                                      Watchdog Cafe
# 32                                         Aroma Cafe
# 33                                       Capitol Cafe
# 34                                        Click! Cafe
# 35                                         Metro Cafe
# 36                               Avenue Cafe & Lounge
# 37                                     Courtyard Cafe
# 38                          14th St Cafe Asian Bistro
# 39                                      Pavilion Cafe
# 40                                           Blu Cafe
# 41                      Kramerbooks & Afterwords Cafe
# 42                                     HUD Cyber Cafe
# 43                                        Garden Café
# 44                                       Cafe Tu-O-Tu
# 45                                       Cascade Cafe
# 46                                      Cafe Phillips
# 47                                         Cafe Eagle
# 48                                         Dacha Cafe
# 49              Firehook Cafe (Natl. Building Museum)
#
#                   categories  \
# 0          French Restaurant
# 1                       Café
# 2                       Café
# 3                       Café
# 4                 Bagel Shop
# 5                       Café
# 6                Coffee Shop
# 7                       Café
# 8        American Restaurant
# 9             Sandwich Place
# 10         French Restaurant
# 11         German Restaurant
# 12                 Cafeteria
# 13       American Restaurant
# 14          Theme Restaurant
# 15                      Café
# 16                      Café
# 17                Food Truck
# 18     Corporate Coffee Shop
# 19                      Café
# 20            Sandwich Place
# 21                Restaurant
# 22                Restaurant
# 23                      Café
# 24             Deli / Bodega
# 25       American Restaurant
# 26                      Café
# 27                      Café
# 28                Food Court
# 29             Deli / Bodega
# 30                      Café
# 31                Food Court
# 32               Coffee Shop
# 33                      Café
# 34     Corporate Coffee Shop
# 35     Corporate Coffee Shop
# 36                Restaurant
# 37                      Café
# 38          Asian Restaurant
# 39                      Café
# 40                      Café
# 41                 Bookstore
# 42       American Restaurant
# 43        Italian Restaurant
# 44  Mediterranean Restaurant
# 45                      Café
# 46            Sandwich Place
# 47        Mexican Restaurant
# 48                    Market
# 49                      Café
#
#                                               address  cc  \
# 0                            1401 Pennsylvania Ave NW  US
# 1                            1331 Pennsylvania Ave NW  US
# 2                                      529 14th St NW  US
# 3                       100 Raoul Wallenberg Place SW  US
# 4                                        2000 K St NW  US
# 5                            1331 Pennsylvania Ave NW  US
# 6                                        1889 F St NW  US
# 7                                        1800 G St NW  US
# 8                                                 NaN  US
# 9                                        1401 H St NW  US
# 10                                     839 17th St NW  US
# 11                                       1331 H St NW  US
# 12                National Museum of American History  US
# 13                           1400 Constitution Ave NW  US
# 14                                        999 E St NW  US
# 15                             818 Connecticut Ave NW  US
# 16                                   1117 10th St. NW  US
# 17                     101-199 Raoul Wallenberg Pl SW  US
# 18                                      500 8th St NW  US
# 19                                    1101 17th St NW  US
# 20                            1050 Connecticut Ave NW  US
# 21                                      1301 K St. NW  US
# 22                           1900 Pennsylvania Ave NW  US
# 23                                       1825 I St NW  US
# 24                                1110 Vermont Ave NW  US
# 25                                       2200 M St NW  US
# 26                                1199 Vermont Ave NW  US
# 27  10th St. & Constitution Ave. NW, Washington, D...  US
# 28                                     616 23rd St NW  US
# 29                                       2400 M St NW  US
# 30                        1145 19th St NW, Rear LOBBY  US
# 31                                        441 G St NW  US
# 32                           2401 Pennsylvania Ave NW  US
# 33                            101 Constitution Ave NW  US
# 34                                       2000 N St NW  US
# 35                                    1400 16th St NW  US
# 36                 1501 Rhode Island Avenue Northwest  US
# 37                                    800-898 G St NW  US
# 38                                    1416 14th St NW  US
# 39                                         7th St. NW  US
# 40                                    1170 22nd St NW  US
# 41                            1517 Connecticut Ave NW  US
# 42                                                NaN  US
# 43                            National Gallery of Art  US
# 44                           2816 Pennsylvania Ave NW  US
# 45                          6th & Constitution Ave NW  US
# 46                                         50 F St NW  US
# 47                                     1414 9th St NW  US
# 48                                     1602 7th St NW  US
# 49                                    401 F Street NW  US
#
#                     city        country  \
# 0             Washington  United States
# 1             Washington  United States
# 2             Washington  United States
# 3                    NaN  United States
# 4             Washington  United States
# 5             Washington  United States
# 6             Washington  United States
# 7             Washington  United States
# 8             Washington  United States
# 9             Washington  United States
# 10            Washington  United States
# 11            Washington  United States
# 12            Washington  United States
# 13            Washington  United States
# 14            Washington  United States
# 15            Washington  United States
# 16            Washington  United States
# 17            Washington  United States
# 18            Washington  United States
# 19            Washington  United States
# 20            Washington  United States
# 21            Washington  United States
# 22            Washington  United States
# 23            Washington  United States
# 24            Washington  United States
# 25            Washington  United States
# 26            Washington  United States
# 27            Washington  United States
# 28            Washington  United States
# 29            Washington  United States
# 30            Washington  United States
# 31            Washington  United States
# 32            Washington  United States
# 33            Washington  United States
# 34  District of Columbia  United States
# 35            Washington  United States
# 36            Washington  United States
# 37            Washington  United States
# 38            Washington  United States
# 39            Washington  United States
# 40            Washington  United States
# 41            Washington  United States
# 42            Washington  United States
# 43            Washington  United States
# 44            Washington  United States
# 45            Washington  United States
# 46            Washington  United States
# 47            Washington  United States
# 48            Washington  United States
# 49            Washington  United States
#
#                                crossStreet  distance  \
# 0                               at 14th St       381
# 1                                      NaN       450
# 2                                      NaN       477
# 3                                      NaN       905
# 4                            at 20th St NW      1117
# 5                                      NaN       613
# 6                            at 19th St NW       647
# 7                   btwn 18th & 19th St NW       660
# 8                                      NaN       543
# 9                            at 14th St NW       735
# 10                              at I St NW       722
# 11                                     NaN       803
# 12                                     NaN       596
# 13  in National Museum of American History       651
# 14                           at 10th St NW       941
# 15                                     NaN       700
# 16                      btwn L & M Sts. NW      1431
# 17                                     NaN       748
# 18                                     NaN      1184
# 19                  btwn L St & Sumner Row      1025
# 20                             at L Street      1024
# 21                                13th St.      1037
# 22                     19th & Pennsylvania       870
# 23                                     NaN       937
# 24                                     NaN      1078
# 25                                     NaN      1574
# 26                                     NaN      1110
# 27                           at 10th St NW       988
# 28                                     NaN      1240
# 29                        btwn L & M St NW      1704
# 30                                     NaN      1241
# 31                                     NaN      1831
# 32                           at 24th St NW      1589
# 33                              2nd Street      2015
# 34                                     NaN      1499
# 35                              at P St NW      1592
# 36                              at 15th St      1471
# 37                                     NaN      1225
# 38                                     NaN      1664
# 39                       Constitution Ave.      1220
# 40       at Sports Club/LA In Ritz-Carlton      1534
# 41                              at Q St NW      1866
# 42                                     NaN      1669
# 43                                     NaN      1497
# 44                          at 29th St. NW      2138
# 45                                     NaN      1667
# 46                  at North Capitol St NW      2305
# 47                             at P St. NW      1909
# 48                                     NaN      2208
# 49                             Fifth St NW      1650
#
#                                      formattedAddress  \
# 0   [1401 Pennsylvania Ave NW (at 14th St), Washin...
# 1   [1331 Pennsylvania Ave NW, Washington, D.C. 20...
# 2   [529 14th St NW, Washington, D.C. 20045, Unite...
# 3   [100 Raoul Wallenberg Place SW, Washington, D....
# 4   [2000 K St NW (at 20th St NW), Washington, D.C...
# 5   [1331 Pennsylvania Ave NW, Washington, D.C. 20...
# 6   [1889 F St NW (at 19th St NW), Washington, D.C...
# 7   [1800 G St NW (btwn 18th & 19th St NW), Washin...
# 8             [Washington, D.C. 20230, United States]
# 9   [1401 H St NW (at 14th St NW), Washington, D.C...
# 10  [839 17th St NW (at I St NW), Washington, D.C....
# 11  [1331 H St NW, Washington, D.C. 20005, United ...
# 12  [National Museum of American History, Washingt...
# 13  [1400 Constitution Ave NW (in National Museum ...
# 14  [999 E St NW (at 10th St NW), Washington, D.C....
# 15  [818 Connecticut Ave NW, Washington, D.C. 2000...
# 16  [1117 10th St. NW (btwn L & M Sts. NW), Washin...
# 17  [101-199 Raoul Wallenberg Pl SW, Washington, D...
# 18  [500 8th St NW, Washington, D.C. 20004, United...
# 19  [1101 17th St NW (btwn L St & Sumner Row), Was...
# 20  [1050 Connecticut Ave NW (at L Street), Washin...
# 21  [1301 K St. NW (13th St.), Washington, D.C. 20...
# 22  [1900 Pennsylvania Ave NW (19th & Pennsylvania...
# 23  [1825 I St NW, Washington, D.C. 20006, United ...
# 24  [1110 Vermont Ave NW, Washington, D.C. 20006, ...
# 25  [2200 M St NW, Washington, D.C. 20037, United ...
# 26  [1199 Vermont Ave NW, Washington, D.C. 20005, ...
# 27  [10th St. & Constitution Ave. NW, Washington, ...
# 28  [616 23rd St NW, Washington, D.C. 20050, Unite...
# 29  [2400 M St NW (btwn L & M St NW), Washington, ...
# 30  [1145 19th St NW, Rear LOBBY, Washington, D.C....
# 31  [441 G St NW, Washington, D.C. 20548, United S...
# 32  [2401 Pennsylvania Ave NW (at 24th St NW), Was...
# 33  [101 Constitution Ave NW (2nd Street), Washing...
# 34  [2000 N St NW, District of Columbia, D.C., Uni...
# 35  [1400 16th St NW (at P St NW), Washington, D.C...
# 36  [1501 Rhode Island Avenue Northwest (at 15th S...
# 37  [800-898 G St NW, Washington, D.C. 20001, Unit...
# 38  [1416 14th St NW, Washington, D.C. 20005, Unit...
# 39  [7th St. NW (Constitution Ave.), Washington, D...
# 40  [1170 22nd St NW (at Sports Club/LA In Ritz-Ca...
# 41  [1517 Connecticut Ave NW (at Q St NW), Washing...
# 42            [Washington, D.C. 20585, United States]
# 43  [National Gallery of Art, Washington, D.C. 200...
# 44  [2816 Pennsylvania Ave NW (at 29th St. NW), Wa...
# 45  [6th & Constitution Ave NW, Washington, D.C. 2...
# 46  [50 F St NW (at North Capitol St NW), Washingt...
# 47  [1414 9th St NW (at P St. NW), Washington, D.C...
# 48  [1602 7th St NW, Washington, D.C. 20001, Unite...
# 49  [401 F Street NW (Fifth St NW), Washington, D....
#
#                                        labeledLatLngs        lat        lng  \
# 0   [{'label': 'display', 'lat': 38.896497, 'lng':...  38.896497 -77.032618
# 1   [{'label': 'display', 'lat': 38.89599871486189...  38.895999 -77.031535
# 2   [{'label': 'display', 'lat': 38.89693256878712...  38.896933 -77.031654
# 3   [{'label': 'display', 'lat': 38.88713574627168...  38.887136 -77.033826
# 4   [{'label': 'display', 'lat': 38.90230187352699...  38.902302 -77.045396
# 5   [{'label': 'display', 'lat': 38.89734056306548...  38.897341 -77.030168
# 6   [{'label': 'display', 'lat': 38.89745645130179...  38.897456 -77.043341
# 7   [{'label': 'display', 'lat': 38.89841208085561...  38.898412 -77.042800
# 8   [{'label': 'display', 'lat': 38.891205, 'lng':...  38.891205 -77.032610
# 9   [{'label': 'display', 'lat': 38.90063965418262...  38.900640 -77.032182
# 10  [{'label': 'display', 'lat': 38.90108222289659...  38.901082 -77.039423
# 11  [{'label': 'display', 'lat': 38.90049562398960...  38.900496 -77.030589
# 12  [{'label': 'display', 'lat': 38.89115875931902...  38.891159 -77.031749
# 13  [{'label': 'display', 'lat': 38.89203513365936...  38.892035 -77.030074
# 14  [{'label': 'display', 'lat': 38.89635356886816...  38.896354 -77.025848
# 15  [{'label': 'display', 'lat': 38.90107884053043...  38.901079 -77.038610
# 16  [{'label': 'display', 'lat': 38.90478739631018...  38.904787 -77.025882
# 17  [{'label': 'display', 'lat': 38.88879608709441...  38.888796 -77.033201
# 18  [{'label': 'display', 'lat': 38.8964674964982,...  38.896467 -77.023030
# 19  [{'label': 'display', 'lat': 38.904046, 'lng':...  38.904046 -77.038714
# 20  [{'label': 'display', 'lat': 38.90373594465046...  38.903736 -77.040248
# 21  [{'label': 'display', 'lat': 38.90268509230859...  38.902685 -77.029823
# 22  [{'label': 'display', 'lat': 38.900005, 'lng':...  38.900005 -77.044268
# 23  [{'label': 'display', 'lat': 38.901919188563, ...  38.901919 -77.042715
# 24  [{'label': 'display', 'lat': 38.904328, 'lng':...  38.904328 -77.033256
# 25  [{'label': 'display', 'lat': 38.90539830292653...  38.905398 -77.048878
# 26  [{'label': 'display', 'lat': 38.90443592373471...  38.904436 -77.032454
# 27  [{'label': 'display', 'lat': 38.89140342548594...  38.891403 -77.026134
# 28  [{'label': 'display', 'lat': 38.89816014142843...  38.898160 -77.050294
# 29  [{'label': 'display', 'lat': 38.90483689364071...  38.904837 -77.051626
# 30  [{'label': 'display', 'lat': 38.90485371182369...  38.904854 -77.043243
# 31  [{'label': 'display', 'lat': 38.89945466633600...  38.899455 -77.016223
# 32  [{'label': 'display', 'lat': 38.90324067012936...  38.903241 -77.051548
# 33  [{'label': 'display', 'lat': 38.89290217302212...  38.892902 -77.013458
# 34  [{'label': 'display', 'lat': 38.90664965116771...  38.906650 -77.045233
# 35  [{'label': 'display', 'lat': 38.90928368589371...  38.909284 -77.037213
# 36  [{'label': 'display', 'lat': 38.90815, 'lng': ...  38.908150 -77.035020
# 37  [{'label': 'display', 'lat': 38.89796249779111...  38.897962 -77.022957
# 38  [{'label': 'display', 'lat': 38.90951696014983...  38.909517 -77.032050
# 39  [{'label': 'display', 'lat': 38.89127450708808...  38.891275 -77.023317
# 40  [{'label': 'display', 'lat': 38.90498210038523...  38.904982 -77.048771
# 41  [{'label': 'display', 'lat': 38.91075587058406...  38.910756 -77.043880
# 42  [{'label': 'display', 'lat': 38.88426455602229...  38.884265 -77.023104
# 43  [{'label': 'display', 'lat': 38.89131983551087...  38.891320 -77.019939
# 44  [{'label': 'display', 'lat': 38.90509566320447...  38.905096 -77.057559
# 45  [{'label': 'display', 'lat': 38.89136062496509...  38.891361 -77.017900
# 46  [{'label': 'display', 'lat': 38.89750944753065...  38.897509 -77.010157
# 47  [{'label': 'display', 'lat': 38.90920662534366...  38.909207 -77.024238
# 48  [{'label': 'display', 'lat': 38.91128687855536...  38.911287 -77.022047
# 49  [{'label': 'display', 'lat': 38.89774355555534...  38.897744 -77.017850
#
#             neighborhood postalCode             state  \
# 0                    NaN      20004              D.C.
# 1                    NaN      20004              D.C.
# 2                    NaN      20045              D.C.
# 3   Southwest Washington        NaN  Washington, D.C.
# 4                    NaN      20006              D.C.
# 5                    NaN      20004              D.C.
# 6                    NaN      20006              D.C.
# 7                    NaN      20006              D.C.
# 8                    NaN      20230              D.C.
# 9                    NaN      20005              D.C.
# 10                   NaN      20006              D.C.
# 11                   NaN      20005              D.C.
# 12                   NaN      20024              D.C.
# 13                   NaN      20560              D.C.
# 14                   NaN      20004              D.C.
# 15                   NaN      20006              D.C.
# 16                   NaN      20001              D.C.
# 17                   NaN      20024              D.C.
# 18                   NaN      20004              D.C.
# 19                   NaN      20036              D.C.
# 20                   NaN      20036              D.C.
# 21                   NaN      20005              D.C.
# 22                   NaN        NaN              D.C.
# 23                   NaN      20006              D.C.
# 24                   NaN      20006              D.C.
# 25                   NaN      20037              D.C.
# 26                   NaN      20005              D.C.
# 27                   NaN      20560              D.C.
# 28                   NaN      20050              D.C.
# 29                   NaN      20037              D.C.
# 30                   NaN      20036              D.C.
# 31                   NaN      20548              D.C.
# 32                   NaN        NaN              D.C.
# 33                   NaN      20001              D.C.
# 34                   NaN        NaN              D.C.
# 35                   NaN      20036              D.C.
# 36                   NaN      20005              D.C.
# 37                   NaN      20001              D.C.
# 38                   NaN      20005              D.C.
# 39                   NaN      20565              D.C.
# 40                   NaN      20037              D.C.
# 41                   NaN      20036              D.C.
# 42                   NaN      20585              D.C.
# 43                   NaN      20001              D.C.
# 44                   NaN      20007              D.C.
# 45                   NaN      20565              D.C.
# 46                   NaN      20001              D.C.
# 47                   NaN      20001              D.C.
# 48                   NaN      20001              D.C.
# 49                   NaN      20001              D.C.
#
#                           id
# 0   4a9b1b0bf964a5206d3420e3
# 1   4eeba201d3e3d34eb11432b1
# 2   4cd2efd240d4594138ae9a41
# 3   4fc26ad7e4b02db73e8950cb
# 4   4aa92f87f964a520575220e3
# 5   4cdc15364006a1434a72dcb2
# 6   44d31e22f964a5203d361fe3
# 7   4a9ffb83f964a520d63d20e3
# 8   57f91c81498e3ba5808c29c1
# 9   4a7b0ecdf964a520e6e91fe3
# 10  4b9931faf964a520d26835e3
# 11  40b13b00f964a52047f71ee3
# 12  4ad0e92af964a52007db20e3
# 13  4c32042f452620a12e5e210f
# 14  40b13b00f964a52079f41ee3
# 15  542b16e4498ea5b0861d5d03
# 16  4b1a7c72f964a520ffea23e3
# 17  4bb61bcfef159c74036b75f7
# 18  4c4616972dcd9c74f7b40a7b
# 19  49d0eb69f964a520405b1fe3
# 20  4b226639f964a520524624e3
# 21  4b5f087cf964a52014a329e3
# 22  4a96b618f964a520ad2620e3
# 23  51112106e4b0c5da227cfbfc
# 24  4cdbfc3c22bd721e238af847
# 25  53762fa0498e37ec0e970d61
# 26  4fe06043e4b01c7416de39f3
# 27  4e85eadf9adf501dc286a798
# 28  4b8ef33af964a520934033e3
# 29  4ccaf5d5b571b60c31c4c865
# 30  4b2903f6f964a5205d9724e3
# 31  4c0fc0b47189c9285592dab6
# 32  4bae0ac5f964a520db7d3be3
# 33  4bbb8216e5b0d13aa3216e7c
# 34  4b5653def964a5208c0b28e3
# 35  4ca0afa27d69b713ec3e3fc2
# 36  4bf59b5c4d5f20a1dec197fe
# 37  4b84126df964a520ea1e31e3
# 38  55c7d79a498e846e84ad8f0c
# 39  4bad124cf964a5209f2a3be3
# 40  4b44eb9ef964a520d5ff25e3
# 41  40b3de00f964a5202b001fe3
# 42  4d89e884bc848cfa7ebacc2b
# 43  4e63e23e7d8b85408a4a84d3
# 44  4a416e1bf964a5204ba51fe3
# 45  4e4e5d45bd4101d0d7a88b94
# 46  4b212c13f964a520ae3724e3
# 47  4d87dff124bf145691eabd5d
# 48  5650d1c138fa31e5c8ca23e1
# 49  50f460a4e4b0447167368a7e

# %%
dataframe_filtered.name
venues_map=folium.Map(location=[latitude, longitude], zoom_start=13)
folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='Conrad Hotel',
    fill=True,
    fill_color='red',
    fill_opacity=0.6
).add_to(venues_map)
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill=True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import types
import pandas as pd
from botocore.client import Config
import ibm_boto3

def __iter__(self): return 0

# @hidden_cell
# The following code accesses a file in your IBM Cloud Object Storage. It includes your credentials.
# You might want to remove those credentials before you share the notebook.
client_fd91e6dceec34f3693494d977ba5026c = ibm_boto3.client(service_name='s3',
    ibm_api_key_id='WYJB67pN1uUDvD_HOJPU_2UEAAOrrpH6EjBPIl1sOL8J',
    ibm_auth_endpoint="https://iam.ng.bluemix.net/oidc/token",
    config=Config(signature_version='oauth'),
    endpoint_url='https://s3-api.us-geo.objectstorage.service.networklayer.com')

body = client_fd91e6dceec34f3693494d977ba5026c.get_object(Bucket='datasciencecapstonebattleofthenei-donotdelete-pr-h7lfs82oavtopg',Key='Sidewalk_Cafe.csv')['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

df_data_1 = pd.read_csv(body)
df_data_1.head()
# Out:
#    OBJECTID_1  OBJECTID SQUARE SUFFIX   LOT IDNUM               OWNER  \
# 0           1         1      4      N  2029  S693      VITTORIO TESTE
# 1           2         2     14           28  S271  TRIANGLE COMM ASSN
# 2           3         3
# 3           4         4
# 4           5         5     15           18  S269            L STREET
#
#                     ADDRESS  AREA_          X          Y  ADDRID
# 0  2600 PENNSYLVANIA AVE NW  787.5  395220.84  137348.04  274801
# 1  2519 PENNSYLVANIA AVE NW    198  395328.86  137364.07  273879
# 2  2507 PENNSYLVANIA AVE NW         395343.02  137352.33  293225
# 3  2513 PENNSYLVANIA Ave NW         395333.74  137361.44  273878
# 4          2524 L STREET NW    200  395287.92  137300.69  273883
